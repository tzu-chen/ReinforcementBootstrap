# %% [markdown]
# # <font size = "10" color = "red"> SAC training - Compact Boson

# %% [markdown]
# ## <font size = "6"> Packages

# %%
#!pip install stable-baselines3
import gym
import math
import numpy as np
from numpy import array, inf, vectorize, repeat, power
from numpy import abs as np_abs
from numpy import sum as np_sum
#from scipy.special import hyp2f1
import mpmath as mp
from mpmath import fp, hyp2f1
from numpy.random import rand
from numpy.linalg import norm
from numpy import array
from numpy import zeros, zeros_like
from numpy import ones, ones_like
from numpy import inf
from numpy import minimum, maximum
import matplotlib.pyplot as plt
import os
from stable_baselines3.sac.policies import MlpPolicy
from stable_baselines3 import SAC
from stable_baselines3.common import results_plotter
from stable_baselines3.common.monitor import Monitor
from itertools import zip_longest
import CFT_Env_Scipy as CFT_Env
import pandas as pd

# %% [markdown]
# ## <font size = "6">Environment Setup

# %% [markdown]
# Main modifications:
#
# -Introduced guess mode:
# When in guess mode the environment is reset to a random state. When in normal mode the environment is reset to the best state so far.
#
# -Agent trapped:
# Introduced a control that terminates the episode if the agent has taken too many steps without improvement.
#
# -Min reward capped:
# When the rewards get smaller than a big multiple of the best reward the episode is terminated. This should avoid divergencies in the loss.
#
# -Mode 2 training:
# Freeze scaling dimensions at the beginning of the training.
#
# -NEW: THE STATE FED TO THE NETWORK IS THE 10 DIMENSIONAL ONE INCLUDING SCALING DIMENSIONS AND OPE COEFFICIENTS, NOT THE ERRORS OF THE 29 CROSSING EQUATION

# %% [markdown]
# The definition of $E_{abs}$ for the Ising model seems to be closer to:
#
# \begin{equation}
# E_{abs} = \sum_{i=1}^{N_z} \left[ \left| 1-z_i \right|^{2\Delta}\sum_{h, \bar{h}}\vphantom{\sum}^{\prime} \left| C_{h,\bar{h}}^{(s)}g_{h,\bar{h}}^{(s)}(z_i, \bar{z}_i)\right| + \left| z_i \right|^{2\Delta}\sum_{h, \bar{h}}\vphantom{\sum}^{\prime} \left| C_{h,\bar{h}}^{(t)}g_{h,\bar{h}}^{(t)}(1 - z_i, 1 - \bar{z}_i)\right| + \left| 1-z_i \right|^{2\Delta} + \left|z_i \right|^{2\Delta}\right]
# \end{equation}

# %% [markdown]
# ### <font color = "red">General CFT Environment: Examples

# %% [markdown]
# #### <font color = "orange" size = "3">Examples 1: Analytic Ising

# %%
spec_Ising_analytic = {
    0: [{'Delta': 4, 'C': 2.44141e-4}, {'Delta': 1, 'C': 0.25}],
    2: [{'Delta': 2, 'C': 0.015625}],
    4: [{'Delta': 4, 'C': 2.19727e-4}],
    6: [{'Delta': 6, 'C': 1.36239e-5}],
}


Ising = CFT_Env.CFT_Env(spec_Ising_analytic, spec_Ising_analytic, Del_Ext = 1/8, s_is_t = True)
print(Ising.full_del_c_spec_flat)
print(Ising.full_spin_spec_flat)
print( Ising.Reward(rand(29, 2)) )
print( Ising.Accuracy(rand(29, 2)) )
# Out:
# [4.00000e+00 2.44141e-04 1.00000e+00 2.50000e-01 2.00000e+00 1.56250e-02
#  4.00000e+00 2.19727e-04 6.00000e+00 1.36239e-05]
# [0 0 2 4 6]
# -0.04832439623292127
# 0.0007470744823699598

# %%
Ising.Full_Spec_List_to_Spec_Dict()
ising_action = array([i**2 for i in range(10)])
Ising.Update_Spec(ising_action)
print(Ising.full_del_c_spec_flat)
# Out:
# [ 4.          1.00024414  5.          9.25       18.         25.015625
#  40.         49.00021973 70.         81.00001362]

# %% [markdown]
# #### <font color = "orange" size = "3">Examples 2 - 1: Analytic Compact boson 1

# %%
spec_s_1_analytic = { 
    0: [{'Delta': 0.4, 'C': 1}], 
    }
spec_t_1_analytic = { 
    0: [{'Delta': 2, 'C': 1e-2}], 
    1: [{'Delta': 1, 'C': -0.1}],
    2: [{'Delta': 2, 'C': 5e-3}],
    }

Compact_Boson_1 = CFT_Env.CFT_Env(spec_s_1_analytic, spec_t_1_analytic, Del_Ext = 0.1, s_Id = 0)
print( Compact_Boson_1.full_del_c_spec_flat )
print( Compact_Boson_1.full_spin_spec_flat )
print( Compact_Boson_1.Reward(rand(30, 2)) )
print( Compact_Boson_1.Accuracy(rand(30, 2)) )
# Out:
# [ 0.4    1.     2.     0.01   1.    -0.1    2.     0.005]
# [0 0 1 2]
# -0.09130990528153392
# 0.001514055913373364

# %%
Compact_Boson_1.Full_Spec_List_to_Spec_Dict()
# Out:
# ({0: [{'Delta': 0.4, 'C': 1.0}]},
#  {0: [{'Delta': 2.0, 'C': 0.01}],
#   1: [{'Delta': 1.0, 'C': -0.1}],
#   2: [{'Delta': 2.0, 'C': 0.005}]})

# %% [markdown]
# #### <font color = "orange" size = "3">Examples 2 - 2: Analytic Compact boson 2

# %%
spec_s_2_analytic = { 
    0: [{'Delta': 0.4, 'C': 1}], 
    2: [{'Delta': 2.4, 'C': 3.57143e-3}],
    3: [{'Delta': 3.4, 'C': 0}]
    }
spec_t_2_analytic = { 
    0: [{'Delta': 2, 'C': 1e-2}], 
    1: [{'Delta': 1, 'C': -0.1}, {'Delta': 3, 'C': -5e-4}],
    2: [{'Delta': 2, 'C': 5e-3}],
    3: [{'Delta': 3, 'C': -1.66667e-4}]
    }

Compact_Boson_2 = CFT_Env.CFT_Env(spec_s_2_analytic, spec_t_2_analytic, Del_Ext = 0.1, s_Id = 0)
print( Compact_Boson_2.full_del_c_spec_flat )
print( Compact_Boson_2.full_spin_spec_flat )
print( Compact_Boson_2.Reward(rand(30, 2)) )
print( Compact_Boson_2.Accuracy(rand(30, 2)) )
# Out:
# [ 4.00000e-01  1.00000e+00  2.40000e+00  3.57143e-03  3.40000e+00
#   0.00000e+00  2.00000e+00  1.00000e-02  1.00000e+00 -1.00000e-01
#   3.00000e+00 -5.00000e-04  2.00000e+00  5.00000e-03  3.00000e+00
#  -1.66667e-04]
# [0 2 3 0 1 1 2 3]
# -0.007908115477068807
# 0.0008284176230883141

# %%
Compact_Boson_2.Full_Spec_List_to_Spec_Dict()
# Out:
# ({0: [{'Delta': 0.4, 'C': 1.0}],
#   2: [{'Delta': 2.4, 'C': 0.00357143}],
#   3: [{'Delta': 3.4, 'C': 0.0}]},
#  {0: [{'Delta': 2.0, 'C': 0.01}],
#   1: [{'Delta': 1.0, 'C': -0.1}, {'Delta': 3.0, 'C': -0.0005}],
#   2: [{'Delta': 2.0, 'C': 0.005}],
#   3: [{'Delta': 3.0, 'C': -0.000166667}]})

# %% [markdown]
# ## <font size = "6">Training

# %% [markdown]
# ### <font color = "red">Training Environment

# %%
class Training_Env_New(gym.Env):
    """
    Creates a general training environment that can be used with different CFTs.
    The input to the Network are the states, not the errors for the crossing equations.
    """     
    def __init__(
                 self, Model, sampled_points,
                 min_state_bound = None, max_state_bound = None,
                 guess_mode_steps = 0, trapped_steps = 100, reward_cap = 100, reward_scale = 1.,
                 guess_size = 6.5, freeze_mask = None, freeze_accuracy = 0.001
                 ):
        """
        Args:
        error_fn:        function for the crossing equations to be used for penalty.
                         Given a state as input should return ||E||.
        accuracy_fn:     function used to compute accuracy. Given a state should return ||E||/E_{abs}
        state_dim:       integer. dimension of the array of variables to be searched.
        initial state:   array of dimension state_dim. Initial values for the variables to be searched.
        min_state_bound: float or array of dimension state_dim. Sets the minimum value for the search of variables. 
                         If a float, the bound is common for all variables.
        max_state_bound: float or array of dimension state_dim. Sets the maximum value for the search of variables. 
                         If a float, the bound is common for all variables.
        gues_mode_steps: integer. Number of steps to be taken in guess mode.
        trapped_steps:   integer. Number of steps without improvement on the best state after which the environment is reset. 
        reward_cap:      float. Resets the environment when the agent finds a state with reward<reward_cap*best_reward. Should increase stability.
        reward_scale:    float. Reward is computed as -reward_scale*||E||
        guess_size:      float or array of dimension state_dim. Sets the search window at each step for the variables.
                         If a float, the guess size is the same for all variables.
        freeze_mask:     array of dimension state_dim containing only 0 and 1. The variables corresponding to indices that are 0 are not changed
                         until the accuracy reach the level freeze_accuracy. This is needed for training in mode 2. If None no variable is frozen,
        freeze_accuracy: float. Value of accuracy at which all the variables are unfrozen if freeze_mask is not None
        """
        self.Model = Model
        self.pts = sampled_points

        self.state_min = min_state_bound #Set minimum for the search window
        self.state_max = max_state_bound #Set maximum for the search window
        self.state_dim = self.Model.state_dim #state_dim
        self.best_reward = None  #Records best reward
        self.best_accuracy = None
        self.best_state = None   #Records best state
        self.scale = reward_scale #Scale the error
        self.guess_mode = True #Controls wheter the algorithm is working in guess mode
        self.guess_mode_steps = guess_mode_steps #Number of steps to take in guess mode
        self.step_counter = 0 #Records the number of steps executed in the environment
        self.not_improving_steps = 0 #Stores the number of steps since last improvement
        self.trapped_steps = trapped_steps #Maximum number of not improving steps after which the environment is reset
        self.current_reward = None  #Current reward for guess mode
        self.improv_hist = [] #Records reward when a new best state is found
        self.reward_cap = reward_cap #Reset the environment when reward>reward_cap*best_reward
        self.guess_size = guess_size #Search window for each parameter
        self.initial_state = self.Model.full_del_c_spec_flat
        #self.error_fn = error_fn
        #self.accuracy_fn = accuracy_fn
        
        #Setup freeze mode is a mask is passed
        if freeze_mask is not None:
                self.freeze_mode = True      
                self.freeze_mask = freeze_mask
                self.freeze_accuracy = freeze_accuracy
        else:
            self.freeze_mode = False    
        
        
        #Initialize action and observation spaces
        self.action_space = gym.spaces.Box(
            np.float32(array([-1. for i in range(self.state_dim)])), np.float32(array([1. for i in range(self.state_dim)]))
            )
        self.observation_space = gym.spaces.Box(
            np.float32(array([-inf for i in range(self.state_dim)])),np.float32(array([inf for i in range(self.state_dim)]))
            )
        
    def step(self, action):
        

        self.step_counter += 1 #Increase step counter 

        if self.guess_mode:
            current_reward = self.Model.Reward(self.pts) * self.scale
            
        if self.freeze_mode: #In freeze_mode freeze some of the parameters during training
            
            acc = self.Model.Accuracy(self.pts)

            if acc < self.freeze_accuracy and not self.guess_mode:
                self.freeze_mode = False

            action = action * self.freeze_mask
                
    
        #self.Model.Update_Spec(action * self.guess_size)

        self.state = self.state + action * self.guess_size
        #print(self.state)
        self.state = np.maximum(self.state_min, self.state)
        self.state = np.minimum(self.state_max, self.state)
        obs = self.state
        self.Model.Update_Spec_with_new_spec(self.state)
        reward = self.Model.Reward(self.pts) * self.scale
        accuracy =  self.Model.Accuracy(self.pts)

        if self.step_counter % 1000 == 0:
            print(f'Step:{self.step_counter}, Best_Reward:{self.best_reward:.6f}, Guess_Mode:{self.guess_mode}, Freeze_Mode:{self.freeze_mode}')
            print(self.best_state)
        
        if self.best_reward is None:
            self.best_reward = reward
            self.best_state = self.state

        if self.guess_mode:

            if self.step_counter > self.guess_mode_steps: #end guess_mode
                self.guess_mode = False
                done = True
            #check update best reward
            if reward > self.best_reward:
                self.best_reward = reward
                self.best_state = self.state
                self.improv_hist.append((self.step_counter, reward, accuracy, self.state))
                self.not_improving_steps = 0


            if reward > current_reward:
                done=True
            else:
                self.not_improving_steps+=1
                done=False

        else:
            #check update best reward and terminate
            if reward > self.best_reward:
                self.best_reward = reward
                self.best_state = self.state
                self.not_improving_steps = 0
                self.improv_hist.append((self.step_counter, reward, self.state))
                done = True
                
            else:
                self.not_improving_steps += 1
                done = False
                
            if reward < self.reward_cap * self.best_reward: #This should limit instabilities and divergencies
                    done = True

        if self.not_improving_steps > self.trapped_steps:
                self.not_improving_steps = 0
                done = True

        info = {}
        return obs, reward, done, info

    def reset(self):
        
        if self.guess_mode:
            #self.state = rand(10)*6.5 #reset to a random state only in guessing mode
            self.state = self.initial_state

        else:
            self.state = self.best_state

        return self.state

# %% [markdown]
# ### <font color = 'red'> Start Training

# %%
spec_s_1_Untrained = { 
    0: [{'Delta': 0.4, 'C': rand()}], 
    }
spec_t_1_Untrained = { 
    0: [{'Delta': 2, 'C': rand()}], 
    1: [{'Delta': 1, 'C': rand()}],
    2: [{'Delta': 2, 'C': rand()}],
    }


Compact_Boson_untrained = CFT_Env.CFT_Env(spec_s_1_Untrained, spec_t_1_Untrained, s_Id = 0, t_Id = 1, Del_Ext = 1/10, s_is_t = False)

# %%
Compact_Boson_untrained.full_del_c_spec_flat
# Out:
# array([0.4       , 0.153025  , 2.        , 0.99767293, 1.        ,
#        0.90784497, 2.        , 0.06402307])

# %%
guess_steps = 7000
total_steps = 1000000
trapped = 50 
reward_scale = 0.005
mask = np.ones(8)
mask[::2] = 0.
initial_state = Compact_Boson_untrained.full_del_c_spec_flat
search_sizes = [0.1, 1, 0.1, 1, 0.1, 1, 0.1, 1]
sampled_points = rand(30, 2)

# %%
env = Training_Env_New(
             Compact_Boson_untrained, sampled_points,
             min_state_bound = -1.0, max_state_bound = 2.0,
             guess_mode_steps=guess_steps, trapped_steps=trapped, 
             reward_scale=reward_scale, guess_size=search_sizes, freeze_mask=mask)

log_dir = "tmp/gym/Compact_Boson_1(Scipy)"
os.makedirs(log_dir, exist_ok = True)
monitor = Monitor(env, log_dir)
model = SAC(MlpPolicy, monitor, verbose = 1, device = 'cuda')
model.learn(total_timesteps = total_steps, log_interval = 100)
# Out:
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.11     |
# |    ep_rew_mean     | -0.364   |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 14       |
# |    time_elapsed    | 14       |
# |    total_timesteps | 211      |
# | train/             |          |
# |    actor_loss      | -8.09    |
# |    critic_loss     | 5.76     |
# |    ent_coef        | 0.968    |
# |    ent_coef_loss   | -0.42    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 110      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.32     |
# |    ep_rew_mean     | -0.636   |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 15       |
# |    time_elapsed    | 28       |
# |    total_timesteps | 443      |
# | train/             |          |
# |    actor_loss      | -8.2     |
# |    critic_loss     | 7.76     |
# |    ent_coef        | 0.905    |
# |    ent_coef_loss   | -1.24    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 342      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.47     |
# |    ep_rew_mean     | -0.743   |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 15       |
# |    time_elapsed    | 43       |
# |    total_timesteps | 690      |
# | train/             |          |
# |    actor_loss      | -8.16    |
# |    critic_loss     | 6.93     |
# |    ent_coef        | 0.842    |
# |    ent_coef_loss   | -2.02    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 589      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.63     |
# |    ep_rew_mean     | -0.806   |
# | time/              |          |
# |    episodes        | 400      |
# |    fps             | 15       |
# |    time_elapsed    | 59       |
# |    total_timesteps | 953      |
# | train/             |          |
# |    actor_loss      | -7.86    |
# |    critic_loss     | 8.92     |
# |    ent_coef        | 0.781    |
# |    ent_coef_loss   | -2.91    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 852      |
# ---------------------------------
# Step:1000, Best_Reward:-0.018773, Guess_Mode:True, Freeze_Mode:True
# [ 0.4         0.6797286   2.          0.8138711   1.          0.00695915
#   2.         -0.4204349 ]
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.68     |
# |    ep_rew_mean     | -0.851   |
# | time/              |          |
# |    episodes        | 500      |
# |    fps             | 16       |
# |    time_elapsed    | 75       |
# |    total_timesteps | 1221     |
# | train/             |          |
# |    actor_loss      | -8       |
# |    critic_loss     | 8.69     |
# |    ent_coef        | 0.722    |
# |    ent_coef_loss   | -3.75    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1120     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.86     |
# |    ep_rew_mean     | -0.915   |
# | time/              |          |
# |    episodes        | 600      |
# |    fps             | 16       |
# |    time_elapsed    | 91       |
# |    total_timesteps | 1507     |
# | train/             |          |
# |    actor_loss      | -6.8     |
# |    critic_loss     | 7.73     |
# |    ent_coef        | 0.665    |
# |    ent_coef_loss   | -4.56    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1406     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.46     |
# |    ep_rew_mean     | -0.759   |
# | time/              |          |
# |    episodes        | 700      |
# |    fps             | 16       |
# |    time_elapsed    | 105      |
# |    total_timesteps | 1753     |
# | train/             |          |
# |    actor_loss      | -6.76    |
# |    critic_loss     | 6.51     |
# |    ent_coef        | 0.62     |
# |    ent_coef_loss   | -5.27    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1652     |
# ---------------------------------
# Step:2000, Best_Reward:-0.018773, Guess_Mode:True, Freeze_Mode:True
# [ 0.4         0.6797286   2.          0.8138711   1.          0.00695915
#   2.         -0.4204349 ]
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.19     |
# |    ep_rew_mean     | -1.06    |
# | time/              |          |
# |    episodes        | 800      |
# |    fps             | 16       |
# |    time_elapsed    | 123      |
# |    total_timesteps | 2072     |
# | train/             |          |
# |    actor_loss      | -5.21    |
# |    critic_loss     | 6.88     |
# |    ent_coef        | 0.566    |
# |    ent_coef_loss   | -6.36    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1971     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.43     |
# |    ep_rew_mean     | -1.16    |
# | time/              |          |
# |    episodes        | 900      |
# |    fps             | 16       |
# |    time_elapsed    | 143      |
# |    total_timesteps | 2415     |
# | train/             |          |
# |    actor_loss      | -4.79    |
# |    critic_loss     | 5.33     |
# |    ent_coef        | 0.512    |
# |    ent_coef_loss   | -6.78    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2314     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.43     |
# |    ep_rew_mean     | -1.07    |
# | time/              |          |
# |    episodes        | 1000     |
# |    fps             | 16       |
# |    time_elapsed    | 163      |
# |    total_timesteps | 2758     |
# | train/             |          |
# |    actor_loss      | -4.33    |
# |    critic_loss     | 4.66     |
# |    ent_coef        | 0.464    |
# |    ent_coef_loss   | -8.62    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2657     |
# ---------------------------------
# Step:3000, Best_Reward:-0.018773, Guess_Mode:True, Freeze_Mode:True
# [ 0.4         0.6797286   2.          0.8138711   1.          0.00695915
#   2.         -0.4204349 ]
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.81     |
# |    ep_rew_mean     | -1.32    |
# | time/              |          |
# |    episodes        | 1100     |
# |    fps             | 16       |
# |    time_elapsed    | 185      |
# |    total_timesteps | 3139     |
# | train/             |          |
# |    actor_loss      | -4.09    |
# |    critic_loss     | 3.42     |
# |    ent_coef        | 0.414    |
# |    ent_coef_loss   | -9.71    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3038     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.14     |
# |    ep_rew_mean     | -1.02    |
# | time/              |          |
# |    episodes        | 1200     |
# |    fps             | 16       |
# |    time_elapsed    | 203      |
# |    total_timesteps | 3453     |
# | train/             |          |
# |    actor_loss      | -3.65    |
# |    critic_loss     | 2.16     |
# |    ent_coef        | 0.377    |
# |    ent_coef_loss   | -11      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3352     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.05     |
# |    ep_rew_mean     | -1       |
# | time/              |          |
# |    episodes        | 1300     |
# |    fps             | 16       |
# |    time_elapsed    | 221      |
# |    total_timesteps | 3758     |
# | train/             |          |
# |    actor_loss      | -3.25    |
# |    critic_loss     | 1.77     |
# |    ent_coef        | 0.344    |
# |    ent_coef_loss   | -12.2    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3657     |
# ---------------------------------
# Step:4000, Best_Reward:-0.018773, Guess_Mode:True, Freeze_Mode:True
# [ 0.4         0.6797286   2.          0.8138711   1.          0.00695915
#   2.         -0.4204349 ]
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.92     |
# |    ep_rew_mean     | -1.33    |
# | time/              |          |
# |    episodes        | 1400     |
# |    fps             | 17       |
# |    time_elapsed    | 243      |
# |    total_timesteps | 4150     |
# | train/             |          |
# |    actor_loss      | -2.67    |
# |    critic_loss     | 1.48     |
# |    ent_coef        | 0.306    |
# |    ent_coef_loss   | -13.5    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4049     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4.1      |
# |    ep_rew_mean     | -1.41    |
# | time/              |          |
# |    episodes        | 1500     |
# |    fps             | 17       |
# |    time_elapsed    | 266      |
# |    total_timesteps | 4560     |
# | train/             |          |
# |    actor_loss      | -2.03    |
# |    critic_loss     | 0.864    |
# |    ent_coef        | 0.27     |
# |    ent_coef_loss   | -14.8    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4459     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.44     |
# |    ep_rew_mean     | -1.07    |
# | time/              |          |
# |    episodes        | 1600     |
# |    fps             | 17       |
# |    time_elapsed    | 286      |
# |    total_timesteps | 4904     |
# | train/             |          |
# |    actor_loss      | -1.83    |
# |    critic_loss     | 0.606    |
# |    ent_coef        | 0.243    |
# |    ent_coef_loss   | -16.2    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4803     |
# ---------------------------------
# Step:5000, Best_Reward:-0.018773, Guess_Mode:True, Freeze_Mode:True
# [ 0.4         0.6797286   2.          0.8138711   1.          0.00695915
#   2.         -0.4204349 ]
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.25     |
# |    ep_rew_mean     | -0.952   |
# | time/              |          |
# |    episodes        | 1700     |
# |    fps             | 17       |
# |    time_elapsed    | 305      |
# |    total_timesteps | 5229     |
# | train/             |          |
# |    actor_loss      | -1.51    |
# |    critic_loss     | 0.553    |
# |    ent_coef        | 0.22     |
# |    ent_coef_loss   | -18      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5128     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.34     |
# |    ep_rew_mean     | -0.377   |
# | time/              |          |
# |    episodes        | 1800     |
# |    fps             | 17       |
# |    time_elapsed    | 319      |
# |    total_timesteps | 5463     |
# | train/             |          |
# |    actor_loss      | -1.3     |
# |    critic_loss     | 0.431    |
# |    ent_coef        | 0.206    |
# |    ent_coef_loss   | -17.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5362     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.87     |
# |    ep_rew_mean     | -0.734   |
# | time/              |          |
# |    episodes        | 1900     |
# |    fps             | 17       |
# |    time_elapsed    | 335      |
# |    total_timesteps | 5750     |
# | train/             |          |
# |    actor_loss      | -1       |
# |    critic_loss     | 0.32     |
# |    ent_coef        | 0.189    |
# |    ent_coef_loss   | -20.5    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5649     |
# ---------------------------------
# Step:6000, Best_Reward:-0.018773, Guess_Mode:True, Freeze_Mode:True
# [ 0.4         0.6797286   2.          0.8138711   1.          0.00695915
#   2.         -0.4204349 ]
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.94     |
# |    ep_rew_mean     | -0.819   |
# | time/              |          |
# |    episodes        | 2000     |
# |    fps             | 17       |
# |    time_elapsed    | 353      |
# |    total_timesteps | 6044     |
# | train/             |          |
# |    actor_loss      | -0.913   |
# |    critic_loss     | 0.23     |
# |    ent_coef        | 0.172    |
# |    ent_coef_loss   | -21.7    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5943     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.8      |
# |    ep_rew_mean     | -0.767   |
# | time/              |          |
# |    episodes        | 2100     |
# |    fps             | 17       |
# |    time_elapsed    | 369      |
# |    total_timesteps | 6324     |
# | train/             |          |
# |    actor_loss      | -0.693   |
# |    critic_loss     | 0.187    |
# |    ent_coef        | 0.157    |
# |    ent_coef_loss   | -22.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6223     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.79     |
# |    ep_rew_mean     | -0.737   |
# | time/              |          |
# |    episodes        | 2200     |
# |    fps             | 17       |
# |    time_elapsed    | 386      |
# |    total_timesteps | 6603     |
# | train/             |          |
# |    actor_loss      | -0.572   |
# |    critic_loss     | 0.157    |
# |    ent_coef        | 0.144    |
# |    ent_coef_loss   | -24.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6502     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.77     |
# |    ep_rew_mean     | -0.7     |
# | time/              |          |
# |    episodes        | 2300     |
# |    fps             | 17       |
# |    time_elapsed    | 402      |
# |    total_timesteps | 6880     |
# | train/             |          |
# |    actor_loss      | -0.585   |
# |    critic_loss     | 0.186    |
# |    ent_coef        | 0.132    |
# |    ent_coef_loss   | -25.6    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6779     |
# ---------------------------------
# Step:7000, Best_Reward:-0.018773, Guess_Mode:True, Freeze_Mode:True
# [ 0.4         0.6797286   2.          0.8138711   1.          0.00695915
#   2.         -0.4204349 ]
# Step:8000, Best_Reward:-0.018773, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.6797286   2.          0.8138711   1.          0.00695915
#   2.         -0.4204349 ]
# Step:9000, Best_Reward:-0.018773, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.6797286   2.          0.8138711   1.          0.00695915
#   2.         -0.4204349 ]
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 28.7     |
# |    ep_rew_mean     | -3.98    |
# | time/              |          |
# |    episodes        | 2400     |
# |    fps             | 17       |
# |    time_elapsed    | 554      |
# |    total_timesteps | 9753     |
# | train/             |          |
# |    actor_loss      | -0.89    |
# |    critic_loss     | 0.116    |
# |    ent_coef        | 0.0595   |
# |    ent_coef_loss   | -23.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9652     |
# ---------------------------------
# Step:10000, Best_Reward:-0.018773, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.6797286   2.          0.8138711   1.          0.00695915
#   2.         -0.4204349 ]
# Step:11000, Best_Reward:-0.018773, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.6797286   2.          0.8138711   1.          0.00695915
#   2.         -0.4204349 ]
# Step:12000, Best_Reward:-0.018773, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.6797286   2.          0.8138711   1.          0.00695915
#   2.         -0.4204349 ]
# Step:13000, Best_Reward:-0.018773, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.6797286   2.          0.8138711   1.          0.00695915
#   2.         -0.4204349 ]
# Step:14000, Best_Reward:-0.018773, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.6797286   2.          0.8138711   1.          0.00695915
#   2.         -0.4204349 ]
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 51       |
# |    ep_rew_mean     | -3.36    |
# | time/              |          |
# |    episodes        | 2500     |
# |    fps             | 17       |
# |    time_elapsed    | 827      |
# |    total_timesteps | 14853    |
# | train/             |          |
# |    actor_loss      | -0.42    |
# |    critic_loss     | 0.0184   |
# |    ent_coef        | 0.016    |
# |    ent_coef_loss   | -18      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 14752    |
# ---------------------------------
# Step:15000, Best_Reward:-0.018773, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.6797286   2.          0.8138711   1.          0.00695915
#   2.         -0.4204349 ]
# Step:16000, Best_Reward:-0.018773, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.6797286   2.          0.8138711   1.          0.00695915
#   2.         -0.4204349 ]
# Step:17000, Best_Reward:-0.018773, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.6797286   2.          0.8138711   1.          0.00695915
#   2.         -0.4204349 ]
# Step:18000, Best_Reward:-0.018773, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.6797286   2.          0.8138711   1.          0.00695915
#   2.         -0.4204349 ]
# Step:19000, Best_Reward:-0.018773, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.6797286   2.          0.8138711   1.          0.00695915
#   2.         -0.4204349 ]
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50.6     |
# |    ep_rew_mean     | -2.76    |
# | time/              |          |
# |    episodes        | 2600     |
# |    fps             | 18       |
# |    time_elapsed    | 1088     |
# |    total_timesteps | 19913    |
# | train/             |          |
# |    actor_loss      | 0.131    |
# |    critic_loss     | 0.0026   |
# |    ent_coef        | 0.00501  |
# |    ent_coef_loss   | -1.63    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 19812    |
# ---------------------------------
# Step:20000, Best_Reward:-0.015192, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         1.74935633  2.          0.25328088  1.          0.64546251
#   2.         -0.4265449 ]
# Step:21000, Best_Reward:-0.010750, Guess_Mode:False, Freeze_Mode:True
# [ 0.4        -0.29827839  2.          0.07545769  1.         -1.
#   2.          0.22789878]
# Step:22000, Best_Reward:-0.010750, Guess_Mode:False, Freeze_Mode:True
# [ 0.4        -0.29827839  2.          0.07545769  1.         -1.
#   2.          0.22789878]
# Step:23000, Best_Reward:-0.007410, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.37005216  2.          0.10810149  1.         -0.33591551
#   2.          0.0230878 ]
# Step:24000, Best_Reward:-0.007410, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.37005216  2.          0.10810149  1.         -0.33591551
#   2.          0.0230878 ]
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50.1     |
# |    ep_rew_mean     | -3.17    |
# | time/              |          |
# |    episodes        | 2700     |
# |    fps             | 18       |
# |    time_elapsed    | 1357     |
# |    total_timesteps | 24926    |
# | train/             |          |
# |    actor_loss      | 0.325    |
# |    critic_loss     | 0.00335  |
# |    ent_coef        | 0.00327  |
# |    ent_coef_loss   | -0.273   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 24825    |
# ---------------------------------
# Step:25000, Best_Reward:-0.007410, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.37005216  2.          0.10810149  1.         -0.33591551
#   2.          0.0230878 ]
# Step:26000, Best_Reward:-0.007410, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.37005216  2.          0.10810149  1.         -0.33591551
#   2.          0.0230878 ]
# Step:27000, Best_Reward:-0.007410, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.37005216  2.          0.10810149  1.         -0.33591551
#   2.          0.0230878 ]
# Step:28000, Best_Reward:-0.007410, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.37005216  2.          0.10810149  1.         -0.33591551
#   2.          0.0230878 ]
# Step:29000, Best_Reward:-0.007410, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.37005216  2.          0.10810149  1.         -0.33591551
#   2.          0.0230878 ]
# Step:30000, Best_Reward:-0.007410, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.37005216  2.          0.10810149  1.         -0.33591551
#   2.          0.0230878 ]
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 51       |
# |    ep_rew_mean     | -2.88    |
# | time/              |          |
# |    episodes        | 2800     |
# |    fps             | 18       |
# |    time_elapsed    | 1618     |
# |    total_timesteps | 30026    |
# | train/             |          |
# |    actor_loss      | 0.381    |
# |    critic_loss     | 0.00626  |
# |    ent_coef        | 0.00279  |
# |    ent_coef_loss   | 1.17     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 29925    |
# ---------------------------------
# Step:31000, Best_Reward:-0.006229, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         1.52224475  2.          0.06910712  1.          0.50290179
#   2.         -0.2396037 ]
# Step:32000, Best_Reward:-0.006229, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         1.52224475  2.          0.06910712  1.          0.50290179
#   2.         -0.2396037 ]
# Step:33000, Best_Reward:-0.006229, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         1.52224475  2.          0.06910712  1.          0.50290179
#   2.         -0.2396037 ]
# Step:34000, Best_Reward:-0.006229, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         1.52224475  2.          0.06910712  1.          0.50290179
#   2.         -0.2396037 ]
# Step:35000, Best_Reward:-0.006229, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         1.52224475  2.          0.06910712  1.          0.50290179
#   2.         -0.2396037 ]
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50.7     |
# |    ep_rew_mean     | -3.99    |
# | time/              |          |
# |    episodes        | 2900     |
# |    fps             | 18       |
# |    time_elapsed    | 1861     |
# |    total_timesteps | 35098    |
# | train/             |          |
# |    actor_loss      | 0.504    |
# |    critic_loss     | 0.00838  |
# |    ent_coef        | 0.00312  |
# |    ent_coef_loss   | -1.69    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 34997    |
# ---------------------------------
# Step:36000, Best_Reward:-0.006229, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         1.52224475  2.          0.06910712  1.          0.50290179
#   2.         -0.2396037 ]
# Step:37000, Best_Reward:-0.006229, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         1.52224475  2.          0.06910712  1.          0.50290179
#   2.         -0.2396037 ]
# Step:38000, Best_Reward:-0.006229, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         1.52224475  2.          0.06910712  1.          0.50290179
#   2.         -0.2396037 ]
# Step:39000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# Step:40000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.6     |
# |    ep_rew_mean     | -3.47    |
# | time/              |          |
# |    episodes        | 3000     |
# |    fps             | 19       |
# |    time_elapsed    | 2099     |
# |    total_timesteps | 40055    |
# | train/             |          |
# |    actor_loss      | 0.441    |
# |    critic_loss     | 0.00766  |
# |    ent_coef        | 0.00265  |
# |    ent_coef_loss   | 1.75     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 39954    |
# ---------------------------------
# Step:41000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# Step:42000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# Step:43000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# Step:44000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# Step:45000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 51       |
# |    ep_rew_mean     | -2.94    |
# | time/              |          |
# |    episodes        | 3100     |
# |    fps             | 19       |
# |    time_elapsed    | 2344     |
# |    total_timesteps | 45155    |
# | train/             |          |
# |    actor_loss      | 0.47     |
# |    critic_loss     | 0.00583  |
# |    ent_coef        | 0.00262  |
# |    ent_coef_loss   | -0.125   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 45054    |
# ---------------------------------
# Step:46000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# Step:47000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# Step:48000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# Step:49000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# Step:50000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 51       |
# |    ep_rew_mean     | -3.27    |
# | time/              |          |
# |    episodes        | 3200     |
# |    fps             | 19       |
# |    time_elapsed    | 2625     |
# |    total_timesteps | 50255    |
# | train/             |          |
# |    actor_loss      | 0.523    |
# |    critic_loss     | 0.00719  |
# |    ent_coef        | 0.00259  |
# |    ent_coef_loss   | 1.39     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 50154    |
# ---------------------------------
# Step:51000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# Step:52000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# Step:53000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# Step:54000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# Step:55000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49       |
# |    ep_rew_mean     | -2.81    |
# | time/              |          |
# |    episodes        | 3300     |
# |    fps             | 19       |
# |    time_elapsed    | 2885     |
# |    total_timesteps | 55151    |
# | train/             |          |
# |    actor_loss      | 0.613    |
# |    critic_loss     | 0.0101   |
# |    ent_coef        | 0.00264  |
# |    ent_coef_loss   | -0.553   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 55050    |
# ---------------------------------
# Step:56000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# Step:57000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# Step:58000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# Step:59000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# Step:60000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.8     |
# |    ep_rew_mean     | -3.7     |
# | time/              |          |
# |    episodes        | 3400     |
# |    fps             | 19       |
# |    time_elapsed    | 3147     |
# |    total_timesteps | 60130    |
# | train/             |          |
# |    actor_loss      | 0.567    |
# |    critic_loss     | 0.0221   |
# |    ent_coef        | 0.00294  |
# |    ent_coef_loss   | 9.68     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 60029    |
# ---------------------------------
# Step:61000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# Step:62000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# Step:63000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# Step:64000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# Step:65000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50.7     |
# |    ep_rew_mean     | -3.3     |
# | time/              |          |
# |    episodes        | 3500     |
# |    fps             | 19       |
# |    time_elapsed    | 3415     |
# |    total_timesteps | 65198    |
# | train/             |          |
# |    actor_loss      | 0.449    |
# |    critic_loss     | 0.00854  |
# |    ent_coef        | 0.00284  |
# |    ent_coef_loss   | -2.48    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 65097    |
# ---------------------------------
# Step:66000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# Step:67000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# Step:68000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# Step:69000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# Step:70000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 51       |
# |    ep_rew_mean     | -1.77    |
# | time/              |          |
# |    episodes        | 3600     |
# |    fps             | 19       |
# |    time_elapsed    | 3685     |
# |    total_timesteps | 70298    |
# | train/             |          |
# |    actor_loss      | 0.558    |
# |    critic_loss     | 0.00656  |
# |    ent_coef        | 0.00218  |
# |    ent_coef_loss   | 1.73     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 70197    |
# ---------------------------------
# Step:71000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# Step:72000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# Step:73000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# Step:74000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# Step:75000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 51       |
# |    ep_rew_mean     | -2.45    |
# | time/              |          |
# |    episodes        | 3700     |
# |    fps             | 19       |
# |    time_elapsed    | 3954     |
# |    total_timesteps | 75398    |
# | train/             |          |
# |    actor_loss      | 0.495    |
# |    critic_loss     | 0.0105   |
# |    ent_coef        | 0.00242  |
# |    ent_coef_loss   | 6.17     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 75297    |
# ---------------------------------
# Step:76000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# Step:77000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# Step:78000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# Step:79000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# Step:80000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 51       |
# |    ep_rew_mean     | -2.71    |
# | time/              |          |
# |    episodes        | 3800     |
# |    fps             | 19       |
# |    time_elapsed    | 4218     |
# |    total_timesteps | 80498    |
# | train/             |          |
# |    actor_loss      | 0.569    |
# |    critic_loss     | 0.011    |
# |    ent_coef        | 0.00287  |
# |    ent_coef_loss   | -4.94    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 80397    |
# ---------------------------------
# Step:81000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# Step:82000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# Step:83000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# Step:84000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# Step:85000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 51       |
# |    ep_rew_mean     | -2.89    |
# | time/              |          |
# |    episodes        | 3900     |
# |    fps             | 19       |
# |    time_elapsed    | 4476     |
# |    total_timesteps | 85598    |
# | train/             |          |
# |    actor_loss      | 0.636    |
# |    critic_loss     | 0.0132   |
# |    ent_coef        | 0.00293  |
# |    ent_coef_loss   | -4.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 85497    |
# ---------------------------------
# Step:86000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# Step:87000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# Step:88000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# Step:89000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# Step:90000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 51       |
# |    ep_rew_mean     | -3.31    |
# | time/              |          |
# |    episodes        | 4000     |
# |    fps             | 19       |
# |    time_elapsed    | 4734     |
# |    total_timesteps | 90698    |
# | train/             |          |
# |    actor_loss      | 0.605    |
# |    critic_loss     | 0.011    |
# |    ent_coef        | 0.00272  |
# |    ent_coef_loss   | 1.03     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 90597    |
# ---------------------------------
# Step:91000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# Step:92000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# Step:93000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# Step:94000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# Step:95000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 51       |
# |    ep_rew_mean     | -2.69    |
# | time/              |          |
# |    episodes        | 4100     |
# |    fps             | 19       |
# |    time_elapsed    | 4984     |
# |    total_timesteps | 95798    |
# | train/             |          |
# |    actor_loss      | 0.528    |
# |    critic_loss     | 0.00871  |
# |    ent_coef        | 0.00273  |
# |    ent_coef_loss   | -0.0976  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 95697    |
# ---------------------------------
# Step:96000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# Step:97000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# Step:98000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# Step:99000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# Step:100000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 51       |
# |    ep_rew_mean     | -1.97    |
# | time/              |          |
# |    episodes        | 4200     |
# |    fps             | 19       |
# |    time_elapsed    | 5232     |
# |    total_timesteps | 100898   |
# | train/             |          |
# |    actor_loss      | 0.426    |
# |    critic_loss     | 0.00375  |
# |    ent_coef        | 0.0025   |
# |    ent_coef_loss   | 2.89     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 100797   |
# ---------------------------------
# Step:101000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# Step:102000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# Step:103000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# Step:104000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# Step:105000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 51       |
# |    ep_rew_mean     | -1.92    |
# | time/              |          |
# |    episodes        | 4300     |
# |    fps             | 19       |
# |    time_elapsed    | 5480     |
# |    total_timesteps | 105998   |
# | train/             |          |
# |    actor_loss      | 0.53     |
# |    critic_loss     | 0.00994  |
# |    ent_coef        | 0.00255  |
# |    ent_coef_loss   | 0.872    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 105897   |
# ---------------------------------
# Step:106000, Best_Reward:-0.003103, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         0.93164694  2.         -0.08889621  1.         -0.30321109
#   2.          0.11077821]
# Step:107000, Best_Reward:-0.002386, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         1.10145038  2.          0.02353019  1.          0.00835949
#   2.         -0.05426335]
# Step:108000, Best_Reward:-0.002386, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         1.10145038  2.          0.02353019  1.          0.00835949
#   2.         -0.05426335]
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.5     |
# |    ep_rew_mean     | -1.23    |
# | time/              |          |
# |    episodes        | 4400     |
# |    fps             | 19       |
# |    time_elapsed    | 5585     |
# |    total_timesteps | 108145   |
# | train/             |          |
# |    actor_loss      | 0.556    |
# |    critic_loss     | 0.00914  |
# |    ent_coef        | 0.00253  |
# |    ent_coef_loss   | -2.75    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 108044   |
# ---------------------------------
# Step:109000, Best_Reward:-0.002386, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         1.10145038  2.          0.02353019  1.          0.00835949
#   2.         -0.05426335]
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 17.6     |
# |    ep_rew_mean     | -1.52    |
# | time/              |          |
# |    episodes        | 4500     |
# |    fps             | 19       |
# |    time_elapsed    | 5670     |
# |    total_timesteps | 109902   |
# | train/             |          |
# |    actor_loss      | 0.467    |
# |    critic_loss     | 0.00909  |
# |    ent_coef        | 0.00279  |
# |    ent_coef_loss   | 1.43     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 109801   |
# ---------------------------------
# Step:110000, Best_Reward:-0.002386, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         1.10145038  2.          0.02353019  1.          0.00835949
#   2.         -0.05426335]
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.71     |
# |    ep_rew_mean     | -0.574   |
# | time/              |          |
# |    episodes        | 4600     |
# |    fps             | 19       |
# |    time_elapsed    | 5688     |
# |    total_timesteps | 110273   |
# | train/             |          |
# |    actor_loss      | 0.485    |
# |    critic_loss     | 0.00696  |
# |    ent_coef        | 0.00292  |
# |    ent_coef_loss   | -1.5     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 110172   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4        |
# |    ep_rew_mean     | -0.561   |
# | time/              |          |
# |    episodes        | 4700     |
# |    fps             | 19       |
# |    time_elapsed    | 5708     |
# |    total_timesteps | 110673   |
# | train/             |          |
# |    actor_loss      | 0.475    |
# |    critic_loss     | 0.00773  |
# |    ent_coef        | 0.00291  |
# |    ent_coef_loss   | -2.91    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 110572   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.26     |
# |    ep_rew_mean     | -0.412   |
# | time/              |          |
# |    episodes        | 4800     |
# |    fps             | 19       |
# |    time_elapsed    | 5724     |
# |    total_timesteps | 110999   |
# | train/             |          |
# |    actor_loss      | 0.502    |
# |    critic_loss     | 0.00633  |
# |    ent_coef        | 0.00274  |
# |    ent_coef_loss   | -1.55    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 110898   |
# ---------------------------------
# Step:111000, Best_Reward:-0.002386, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         1.10145038  2.          0.02353019  1.          0.00835949
#   2.         -0.05426335]
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.03     |
# |    ep_rew_mean     | -0.391   |
# | time/              |          |
# |    episodes        | 4900     |
# |    fps             | 19       |
# |    time_elapsed    | 5738     |
# |    total_timesteps | 111302   |
# | train/             |          |
# |    actor_loss      | 0.491    |
# |    critic_loss     | 0.00734  |
# |    ent_coef        | 0.0028   |
# |    ent_coef_loss   | -0.0119  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 111201   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3        |
# |    ep_rew_mean     | -0.393   |
# | time/              |          |
# |    episodes        | 5000     |
# |    fps             | 19       |
# |    time_elapsed    | 5753     |
# |    total_timesteps | 111602   |
# | train/             |          |
# |    actor_loss      | 0.493    |
# |    critic_loss     | 0.00612  |
# |    ent_coef        | 0.00274  |
# |    ent_coef_loss   | 0.847    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 111501   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.12     |
# |    ep_rew_mean     | -0.407   |
# | time/              |          |
# |    episodes        | 5100     |
# |    fps             | 19       |
# |    time_elapsed    | 5768     |
# |    total_timesteps | 111914   |
# ...
# |    ep_len_mean     | 1.97     |
# |    ep_rew_mean     | -0.0358  |
# | time/              |          |
# |    episodes        | 367600   |
# |    fps             | 20       |
# |    time_elapsed    | 49189    |
# |    total_timesteps | 994841   |
# | train/             |          |
# |    actor_loss      | 0.0457   |
# |    critic_loss     | 2.2e-05  |
# |    ent_coef        | 0.00063  |
# |    ent_coef_loss   | -0.775   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 994740   |
# ---------------------------------
# Step:995000, Best_Reward:-0.000305, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         1.03150803  2.          0.00422376  1.         -0.08631283
#   2.          0.00298208]
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.98     |
# |    ep_rew_mean     | -0.0357  |
# | time/              |          |
# |    episodes        | 367700   |
# |    fps             | 20       |
# |    time_elapsed    | 49199    |
# |    total_timesteps | 995039   |
# | train/             |          |
# |    actor_loss      | 0.0445   |
# |    critic_loss     | 4.66e-05 |
# |    ent_coef        | 0.000625 |
# |    ent_coef_loss   | -1.95    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 994938   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.98     |
# |    ep_rew_mean     | -0.0359  |
# | time/              |          |
# |    episodes        | 367800   |
# |    fps             | 20       |
# |    time_elapsed    | 49209    |
# |    total_timesteps | 995237   |
# | train/             |          |
# |    actor_loss      | 0.045    |
# |    critic_loss     | 3.82e-05 |
# |    ent_coef        | 0.000622 |
# |    ent_coef_loss   | -1.16    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 995136   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2        |
# |    ep_rew_mean     | -0.0365  |
# | time/              |          |
# |    episodes        | 367900   |
# |    fps             | 20       |
# |    time_elapsed    | 49219    |
# |    total_timesteps | 995437   |
# | train/             |          |
# |    actor_loss      | 0.0457   |
# |    critic_loss     | 4.38e-05 |
# |    ent_coef        | 0.000601 |
# |    ent_coef_loss   | -1.55    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 995336   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.99     |
# |    ep_rew_mean     | -0.0362  |
# | time/              |          |
# |    episodes        | 368000   |
# |    fps             | 20       |
# |    time_elapsed    | 49229    |
# |    total_timesteps | 995636   |
# | train/             |          |
# |    actor_loss      | 0.0445   |
# |    critic_loss     | 2.93e-05 |
# |    ent_coef        | 0.000595 |
# |    ent_coef_loss   | 0.474    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 995535   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.96     |
# |    ep_rew_mean     | -0.0357  |
# | time/              |          |
# |    episodes        | 368100   |
# |    fps             | 20       |
# |    time_elapsed    | 49238    |
# |    total_timesteps | 995832   |
# | train/             |          |
# |    actor_loss      | 0.0438   |
# |    critic_loss     | 2.44e-05 |
# |    ent_coef        | 0.000595 |
# |    ent_coef_loss   | 0.885    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 995731   |
# ---------------------------------
# Step:996000, Best_Reward:-0.000305, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         1.03150803  2.          0.00422376  1.         -0.08631283
#   2.          0.00298208]
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.96     |
# |    ep_rew_mean     | -0.0355  |
# | time/              |          |
# |    episodes        | 368200   |
# |    fps             | 20       |
# |    time_elapsed    | 49248    |
# |    total_timesteps | 996028   |
# | train/             |          |
# |    actor_loss      | 0.0449   |
# |    critic_loss     | 3.67e-05 |
# |    ent_coef        | 0.000606 |
# |    ent_coef_loss   | -1.67    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 995927   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.98     |
# |    ep_rew_mean     | -0.0359  |
# | time/              |          |
# |    episodes        | 368300   |
# |    fps             | 20       |
# |    time_elapsed    | 49258    |
# |    total_timesteps | 996226   |
# | train/             |          |
# |    actor_loss      | 0.043    |
# |    critic_loss     | 3.45e-05 |
# |    ent_coef        | 0.000605 |
# |    ent_coef_loss   | -2.45    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 996125   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.98     |
# |    ep_rew_mean     | -0.0358  |
# | time/              |          |
# |    episodes        | 368400   |
# |    fps             | 20       |
# |    time_elapsed    | 49268    |
# |    total_timesteps | 996424   |
# | train/             |          |
# |    actor_loss      | 0.0471   |
# |    critic_loss     | 3.3e-05  |
# |    ent_coef        | 0.000624 |
# |    ent_coef_loss   | -0.619   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 996323   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2        |
# |    ep_rew_mean     | -0.0363  |
# | time/              |          |
# |    episodes        | 368500   |
# |    fps             | 20       |
# |    time_elapsed    | 49278    |
# |    total_timesteps | 996624   |
# | train/             |          |
# |    actor_loss      | 0.0456   |
# |    critic_loss     | 4.3e-05  |
# |    ent_coef        | 0.0006   |
# |    ent_coef_loss   | -0.108   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 996523   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.96     |
# |    ep_rew_mean     | -0.0357  |
# | time/              |          |
# |    episodes        | 368600   |
# |    fps             | 20       |
# |    time_elapsed    | 49288    |
# |    total_timesteps | 996820   |
# | train/             |          |
# |    actor_loss      | 0.0469   |
# |    critic_loss     | 3.97e-05 |
# |    ent_coef        | 0.00059  |
# |    ent_coef_loss   | -0.147   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 996719   |
# ---------------------------------
# Step:997000, Best_Reward:-0.000305, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         1.03150803  2.          0.00422376  1.         -0.08631283
#   2.          0.00298208]
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2        |
# |    ep_rew_mean     | -0.0363  |
# | time/              |          |
# |    episodes        | 368700   |
# |    fps             | 20       |
# |    time_elapsed    | 49298    |
# |    total_timesteps | 997020   |
# | train/             |          |
# |    actor_loss      | 0.0445   |
# |    critic_loss     | 2.12e-05 |
# |    ent_coef        | 0.000602 |
# |    ent_coef_loss   | 0.733    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 996919   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2        |
# |    ep_rew_mean     | -0.0361  |
# | time/              |          |
# |    episodes        | 368800   |
# |    fps             | 20       |
# |    time_elapsed    | 49308    |
# |    total_timesteps | 997220   |
# | train/             |          |
# |    actor_loss      | 0.0439   |
# |    critic_loss     | 8.56e-05 |
# |    ent_coef        | 0.000623 |
# |    ent_coef_loss   | 1.28     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 997119   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.97     |
# |    ep_rew_mean     | -0.0359  |
# | time/              |          |
# |    episodes        | 368900   |
# |    fps             | 20       |
# |    time_elapsed    | 49317    |
# |    total_timesteps | 997417   |
# | train/             |          |
# |    actor_loss      | 0.0455   |
# |    critic_loss     | 3.44e-05 |
# |    ent_coef        | 0.000629 |
# |    ent_coef_loss   | 0.772    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 997316   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2        |
# |    ep_rew_mean     | -0.0361  |
# | time/              |          |
# |    episodes        | 369000   |
# |    fps             | 20       |
# |    time_elapsed    | 49327    |
# |    total_timesteps | 997617   |
# | train/             |          |
# |    actor_loss      | 0.0457   |
# |    critic_loss     | 6.34e-05 |
# |    ent_coef        | 0.000625 |
# |    ent_coef_loss   | 0.537    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 997516   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.96     |
# |    ep_rew_mean     | -0.0358  |
# | time/              |          |
# |    episodes        | 369100   |
# |    fps             | 20       |
# |    time_elapsed    | 49337    |
# |    total_timesteps | 997813   |
# | train/             |          |
# |    actor_loss      | 0.0456   |
# |    critic_loss     | 3.51e-05 |
# |    ent_coef        | 0.000622 |
# |    ent_coef_loss   | -0.143   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 997712   |
# ---------------------------------
# Step:998000, Best_Reward:-0.000305, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         1.03150803  2.          0.00422376  1.         -0.08631283
#   2.          0.00298208]
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2        |
# |    ep_rew_mean     | -0.0363  |
# | time/              |          |
# |    episodes        | 369200   |
# |    fps             | 20       |
# |    time_elapsed    | 49347    |
# |    total_timesteps | 998013   |
# | train/             |          |
# |    actor_loss      | 0.0452   |
# |    critic_loss     | 1.96e-05 |
# |    ent_coef        | 0.000615 |
# |    ent_coef_loss   | -0.423   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 997912   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.02     |
# |    ep_rew_mean     | -0.036   |
# | time/              |          |
# |    episodes        | 369300   |
# |    fps             | 20       |
# |    time_elapsed    | 49357    |
# |    total_timesteps | 998215   |
# | train/             |          |
# |    actor_loss      | 0.0463   |
# |    critic_loss     | 4.16e-05 |
# |    ent_coef        | 0.000625 |
# |    ent_coef_loss   | 0.0528   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 998114   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.97     |
# |    ep_rew_mean     | -0.0356  |
# | time/              |          |
# |    episodes        | 369400   |
# |    fps             | 20       |
# |    time_elapsed    | 49367    |
# |    total_timesteps | 998412   |
# | train/             |          |
# |    actor_loss      | 0.0439   |
# |    critic_loss     | 6.67e-05 |
# |    ent_coef        | 0.000621 |
# |    ent_coef_loss   | -0.33    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 998311   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.01     |
# |    ep_rew_mean     | -0.0365  |
# | time/              |          |
# |    episodes        | 369500   |
# |    fps             | 20       |
# |    time_elapsed    | 49377    |
# |    total_timesteps | 998613   |
# | train/             |          |
# |    actor_loss      | 0.0454   |
# |    critic_loss     | 3.02e-05 |
# |    ent_coef        | 0.000623 |
# |    ent_coef_loss   | 0.537    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 998512   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.98     |
# |    ep_rew_mean     | -0.0359  |
# | time/              |          |
# |    episodes        | 369600   |
# |    fps             | 20       |
# |    time_elapsed    | 49387    |
# |    total_timesteps | 998811   |
# | train/             |          |
# |    actor_loss      | 0.047    |
# |    critic_loss     | 5.06e-05 |
# |    ent_coef        | 0.000627 |
# |    ent_coef_loss   | 3.87     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 998710   |
# ---------------------------------
# Step:999000, Best_Reward:-0.000305, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         1.03150803  2.          0.00422376  1.         -0.08631283
#   2.          0.00298208]
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.98     |
# |    ep_rew_mean     | -0.036   |
# | time/              |          |
# |    episodes        | 369700   |
# |    fps             | 20       |
# |    time_elapsed    | 49397    |
# |    total_timesteps | 999009   |
# | train/             |          |
# |    actor_loss      | 0.0469   |
# |    critic_loss     | 4.21e-05 |
# |    ent_coef        | 0.000615 |
# |    ent_coef_loss   | -4.47    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 998908   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.02     |
# |    ep_rew_mean     | -0.0363  |
# | time/              |          |
# |    episodes        | 369800   |
# |    fps             | 20       |
# |    time_elapsed    | 49407    |
# |    total_timesteps | 999211   |
# | train/             |          |
# |    actor_loss      | 0.0446   |
# |    critic_loss     | 2.99e-05 |
# |    ent_coef        | 0.000602 |
# |    ent_coef_loss   | -0.163   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 999110   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.02     |
# |    ep_rew_mean     | -0.0362  |
# | time/              |          |
# |    episodes        | 369900   |
# |    fps             | 20       |
# |    time_elapsed    | 49417    |
# |    total_timesteps | 999413   |
# | train/             |          |
# |    actor_loss      | 0.0462   |
# |    critic_loss     | 5.44e-05 |
# |    ent_coef        | 0.0006   |
# |    ent_coef_loss   | 0.599    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 999312   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.01     |
# |    ep_rew_mean     | -0.0365  |
# | time/              |          |
# |    episodes        | 370000   |
# |    fps             | 20       |
# |    time_elapsed    | 49427    |
# |    total_timesteps | 999614   |
# | train/             |          |
# |    actor_loss      | 0.0463   |
# |    critic_loss     | 8.84e-05 |
# |    ent_coef        | 0.000601 |
# |    ent_coef_loss   | 3.02     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 999513   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.98     |
# |    ep_rew_mean     | -0.036   |
# | time/              |          |
# |    episodes        | 370100   |
# |    fps             | 20       |
# |    time_elapsed    | 49437    |
# |    total_timesteps | 999812   |
# | train/             |          |
# |    actor_loss      | 0.0453   |
# |    critic_loss     | 3.32e-05 |
# |    ent_coef        | 0.000603 |
# |    ent_coef_loss   | -1.46    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 999711   |
# ---------------------------------
# Step:1000000, Best_Reward:-0.000305, Guess_Mode:False, Freeze_Mode:True
# [ 0.4         1.03150803  2.          0.00422376  1.         -0.08631283
#   2.          0.00298208]

# %%
Compact_Boson_trained = CFT_Env.CFT_Env(spec_s_1_Untrained, spec_t_1_Untrained, s_Id = 0, t_Id = 1, Del_Ext = 1/10, s_is_t = False)
Compact_Boson_trained.Update_Spec_with_new_spec(env.improv_hist[-1][-1])
print(f'Reward:{Compact_Boson_trained.Reward(sampled_points)}, Accuracy:{Compact_Boson_trained.Accuracy(sampled_points)}')
Compact_Boson_trained.Full_Spec_List_to_Spec_Dict()
# Out:
# Reward:-0.06091755769041502, Accuracy:0.0012224957906982925
# ({0: [{'Delta': 0.4, 'C': 1.0315080285072327}]},
#  {0: [{'Delta': 2.0, 'C': 0.004223763942718506}],
#   1: [{'Delta': 1.0, 'C': -0.08631283044815063}],
#   2: [{'Delta': 2.0, 'C': 0.0029820799827575684}]})

# %%
data = {'Step':[], 'Delta_s_0':[], 'C_s_0':[], 'Delta_t_0':[], 'C_t_0':[], 'Delta_t_1':[], 'C_t_1':[], 'Delta_t_2':[], 'C_t_2':[], 'Reward':[] }
df = pd.DataFrame(data = data)
history_list = list(map(lambda x:  [x[0]] + list(x[-1]) + [x[1]], env.improv_hist))
history_list = list(map(lambda x: dict(zip(['Step', 'Delta_s_0', 'C_s_0', 'Delta_t_0', 'C_t_0', 'Delta_t_1', 'C_t_1', 'Delta_t_2', 'C_t_2', 'Reward'], x)), history_list))
df = df.append(history_list)

# %%
df.to_csv('Compact_Boson_1_Training_Scipy.csv')
df
# Out:
#         Step  Delta_s_0     C_s_0  Delta_t_0     C_t_0  Delta_t_1     C_t_1  \
# 0        2.0        0.4  1.820826        2.0  0.096949        1.0  2.000000
# 1        3.0        0.4 -0.672275        2.0  0.614071        1.0  1.534044
# 2       19.0        0.4 -0.486036        2.0  1.327874        1.0  0.508719
# 3       23.0        0.4 -0.394347        2.0  0.563414        1.0  0.525086
# 4       44.0        0.4 -0.585421        2.0  0.554846        1.0  0.036764
# 5       77.0        0.4  0.770611        2.0  0.155014        1.0  1.060510
# 6       96.0        0.4  0.679729        2.0  0.813871        1.0  0.006959
# 7    19581.0        0.4  1.067564        2.0 -0.047978        1.0  0.218667
# 8    19658.0        0.4  1.749356        2.0  0.253281        1.0  0.645463
# 9    20830.0        0.4 -0.316383        2.0  0.263357        1.0 -1.000000
# 10   20889.0        0.4 -0.298278        2.0  0.075458        1.0 -1.000000
# 11   22172.0        0.4  0.370052        2.0  0.108101        1.0 -0.335916
# 12   30100.0        0.4  1.522245        2.0  0.069107        1.0  0.502902
# 13   38284.0        0.4  0.470714        2.0 -0.046621        1.0 -0.405577
# 14   38538.0        0.4  0.696094        2.0  0.000124        1.0 -0.417853
# 15   38635.0        0.4  1.293855        2.0  0.054813        1.0 -0.061992
# 16   38641.0        0.4  0.966489        2.0  0.061405        1.0  0.116286
# 17   38645.0        0.4  0.981242        2.0 -0.149462        1.0 -0.012776
# 18   38678.0        0.4  0.931647        2.0 -0.088896        1.0 -0.303211
# 19  106853.0        0.4  1.101450        2.0  0.023530        1.0  0.008359
# 20  317880.0        0.4  0.974646        2.0  0.098876        1.0 -0.047253
# 21  421114.0        0.4  0.923943        2.0  0.011563        1.0 -0.103694
# 22  452274.0        0.4  0.906054        2.0  0.052322        1.0 -0.159098
# 23  529634.0        0.4  0.964641        2.0  0.066566        1.0 -0.097709
# 24  539238.0        0.4  1.031508        2.0  0.004224        1.0 -0.086313
#
#     Delta_t_2     C_t_2    Reward
# 0         2.0 -0.007689 -0.092436
# 1         2.0 -0.874300 -0.058717
# 2         2.0 -0.889679 -0.042561
# 3         2.0 -0.605133 -0.036472
# 4         2.0 -0.245162 -0.032163
# 5         2.0 -0.346563 -0.031839
# 6         2.0 -0.420435 -0.018773
# 7         2.0 -0.245586 -0.017906
# 8         2.0 -0.426545 -0.015192
# 9         2.0  0.121165 -0.012931
# 10        2.0  0.227899 -0.010750
# 11        2.0  0.023088 -0.007410
# 12        2.0 -0.239604 -0.006229
# 13        2.0  0.112318 -0.005352
# 14        2.0  0.148313 -0.005305
# 15        2.0  0.016807 -0.005013
# 16        2.0 -0.091773 -0.004882
# 17        2.0  0.030236 -0.004021
# 18        2.0  0.110778 -0.003103
# 19        2.0 -0.054263 -0.002386
# 20        2.0 -0.044546 -0.002150
# 21        2.0  0.006385 -0.001714
# 22        2.0  0.000705 -0.001393
# 23        2.0 -0.017496 -0.001280
# 24        2.0  0.002982 -0.000305

# %%
Compact_Boson_tmp = CFT_Env.CFT_Env(spec_s_1_Untrained, spec_t_1_Untrained, s_Id = 0, t_Id = 1, Del_Ext = 1/10, s_is_t = False)
Compact_Boson_tmp.Update_Spec_with_new_spec(env.improv_hist[-4][-1])

# %%
pts_tmp = rand(30,2)
print(f'Look_Best_Reward: {Compact_Boson_tmp.Reward(pts_tmp)}, Look_Best_Accuracy: {Compact_Boson_tmp.Accuracy(pts_tmp)}')
print(f'Trained_Reward:{Compact_Boson_trained.Reward(pts_tmp)}, Trained_Accuracy:{Compact_Boson_trained.Accuracy(pts_tmp)}')
print(f'Compact_Boson_1.Reward(pts_tmp)')
# Out:
# Look_Best_Reward: -0.3433205937134069, Look_Best_Accuracy: 0.007019739977501752
# Trained_Reward:-0.049479210247407215, Trained_Accuracy:0.0009923423116912338
# -0.07739862833652655

# %%
steps=[]
rew=[]
for el in env.improv_hist:
        steps.append(el[0])
        rew.append(el[1])
        
plt.plot(steps,rew, '-o')
plt.xlabel('Steps')
plt.ylabel('Reward')
plt.title('New best rewards')
plt.show()

min_index=len(rew)
for i,step in enumerate(steps):
        if step>guess_steps:
                min_index=i
                break
                
plt.plot(steps[:min_index],rew[:min_index], '-o')
plt.title('New best rewards in guess mode')
plt.xlabel('Steps')
plt.ylabel('Reward')
plt.show()
plt.plot(steps[min_index:],rew[min_index:])
plt.title('New best rewards in normal mode')
plt.xlabel('Steps')
plt.ylabel('Reward')
plt.show()

# %%
def moving_average(values, window):
    """
    Smooth values by doing a moving average
    :param values: (numpy array)
    :param window: (int)
    :return: (numpy array)
    """
    weights = np.repeat(1.0, window) / window
    return np.convolve(values, weights, 'valid')

def plot_results(log_folder, start=0, title='Learning Curve'):
    """
    plot the results

    :param log_folder: (str) the save location of the results to plot
    :param title: (str) the title of the task to plot
    """
    x, y = results_plotter.ts2xy(results_plotter.load_results(log_folder), 'timesteps')
    x=x[start:]
    y=y[start:]
    y = moving_average(y, window=50)
    # Truncate x
    x = x[len(x) - len(y):]

    fig = plt.figure(title)
    plt.plot(x, y)
    plt.xlabel('Number of Timesteps')
    plt.ylabel('Rewards')
    plt.title(title + " Smoothed")
    plt.show()
    
plot_results(log_dir)
#plot_results(log_dir, start=guess_steps) #Plot only results after guess mode
